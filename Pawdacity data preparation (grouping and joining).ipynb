# %% [markdown]
# ## Business Problem:

# %% [markdown]
# Pawdacity is a leading pet store chain in Wyoming with 13 stores throughout the state. This year, Pawdacity would like to expand and open a 14th store. Your manager has asked you to perform an analysis to recommend the city for Pawdacity’s newest store, based on predicted yearly sales.

# %% [markdown]
# Your manager has given you the following information to work with:
#
# 1- The monthly sales data for all of the Pawdacity stores for the year 2010.
#
# 2- NAICS data on the most current sales of all competitor stores where total sales is equal to 12 months of sales.
#
# 3- A partially parsed data file that can be used for population numbers.
#
# 4- Demographic data (Households with individuals under 18, Land Area, Population Density, and Total Families) for each city and county in the state of Wyoming. For people who are unfamiliar with the US city system, a state contains counties and counties contains one or more cities.

# %% [markdown]
# To properly build the model, and select predictor variables, create a dataset with the following columns:
#
# City
#
# 2010 Census Population
#
# Total Pawdacity Sales
#
# Households with Under 18
#
# Land Area
#
# Population Density
#
# Total Families

# %% [markdown]
# If you’ve done everything correctly, the sum for each of the above columns should be:
#
# Census Population: 213,862
#
# Total Pawdacity Sales: 3,773,304
#
# Households with Under 18: 34,064
#
# Land Area: 33,071
#
# Population Density: 63
#
# Total Families: 62,653
#
# with 11 rows of data

# %%
# import the required packages:

import pandas as pd #for data manipulations and analysis
import numpy as np #to support arrays and mathematical functions
import os #allows to interface with the underlying operating system that Python is running on
import matplotlib.pyplot as plt #to create plots
#import sklearn 
from sklearn import linear_model #for machine learning functions 
from sklearn.linear_model import LinearRegression 
from sklearn.cross_validation import train_test_split #For machine learning functions
import statsmodels.api as sm  #for the estimation of many different statistical models
import seaborn as sns #for data visualization
# %matplotlib inline

# %%
#What files do we have?
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'p2-2010-pawdacity-monthly-sales-p2-2010-pawdacity-monthly-sales.csv',
#  'p2-partially-parsed-wy-web-scrape.csv',
#  'p2-wy-453910-naics-data.csv',
#  'p2-wy-demographic-data.csv',
#  'Pawdacity data preparation (grouping and joining).ipynb']

# %%
#loading the files
sales_2010 = pd.read_csv('p2-2010-pawdacity-monthly-sales-p2-2010-pawdacity-monthly-sales.csv')
parsed_web = pd.read_csv('p2-partially-parsed-wy-web-scrape.csv')
demographic = pd.read_csv('p2-wy-demographic-data.csv')

# %%
sales_2010
# Out:
#          NAME                       ADDRESS          CITY STATE    ZIP  \
# 0   Pawdacity               509 Fort St # A       Buffalo    WY  82834
# 1   Pawdacity  601 SE Wyoming Blvd Unit 252        Casper    WY  82609
# 2   Pawdacity             3769 E Lincolnway      Cheyenne    WY  82001
# 3   Pawdacity             2625 Big Horn Ave          Cody    WY  82414
# 4   Pawdacity                  123 S 2nd St       Douglas    WY  82633
# 5   Pawdacity                   932 Main St      Evanston    WY  82930
# 6   Pawdacity              200 E Lakeway Rd      Gillette    WY  82718
# 7   Pawdacity                 180 S Bent St        Powell    WY  82435
# 8   Pawdacity                 512 E Main St      Riverton    WY  82501
# 9   Pawdacity           2706 Commercial Way  Rock Springs    WY  82901
# 10  Pawdacity     1842 Sugarland Dr Ste 113      Sheridan    WY  82801
#
#     January  February  March  April    May   June   July  August  September  \
# 0     16200     13392  14688  17064  18360  14040  12960   19224      15984
# 1     29160     21600  27000  27648  29160  27216  25488   25704      22896
# 2     79920     70632  79056  77544  73656  77976  73872   77544      78516
# 3     19440     15984  19008  18144  16632  17496  18792   20304      19224
# 4     16200     13392  14688  17064  18360  14040  12960   19224      15984
# 5     24840     21168  21600  22248  24192  24624  25488   25704      22032
# 6     47520     41796  48384  47088  42336  41904  42120   47088      49032
# 7     20520     17928  20304  21168  21600  17928  18144   18576      20304
# 8     27000     22032  28512  26784  25920  24192  25056   22896      25488
# 9     21600     19872  22248  20952  17496  24840  22464   21816      21384
# 10    27000     26352  28080  22032  21168  29376  25920   20304      33696
#
#     October  November  December
# 0     13392     13176     16848
# 1     25272     28944     27648
# 2     74520     74736     79920
# 3     18144     18576     16632
# 4     29808     17496     18792
# 5     21168     25920     24840
# 6     48168     42984     44712
# 7     21168     17496     18792
# 8     26352     26784     22248
# 9     20304     22032     18576
# 10    23760     25056     25488

# %%
sales_2010.shape
# Out:
# (11, 17)

# %%
sales_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 17 columns):
# NAME         11 non-null object
# ADDRESS      11 non-null object
# CITY         11 non-null object
# STATE        11 non-null object
# ZIP          11 non-null int64
# January      11 non-null int64
# February     11 non-null int64
# March        11 non-null int64
# April        11 non-null int64
# May          11 non-null int64
# June         11 non-null int64
# July         11 non-null int64
# August       11 non-null int64
# September    11 non-null int64
# October      11 non-null int64
# November     11 non-null int64
# December     11 non-null int64
# dtypes: int64(13), object(4)
# memory usage: 1.5+ KB

# %%
#with the sales dataset, we can find the Total Pawdacity Sales and cities
sales_2010 = sales_2010.drop(['NAME','ADDRESS', 'STATE', 'ZIP'], axis = 1)
sales_2010 = sales_2010.groupby('CITY').sum().reset_index()
num_sales = sales_2010.drop('CITY', axis = 1)
sales_2010['Total Pawdacity Sales'] = num_sales.sum(axis = 1)
sales_2010 = sales_2010.filter(['CITY', 'Total Pawdacity Sales'], axis = 1)
sales_2010
# Out:
#             CITY  Total Pawdacity Sales
# 0        Buffalo                 185328
# 1         Casper                 317736
# 2       Cheyenne                 917892
# 3           Cody                 218376
# 4        Douglas                 208008
# 5       Evanston                 283824
# 6       Gillette                 543132
# 7         Powell                 233928
# 8       Riverton                 303264
# 9   Rock Springs                 253584
# 10      Sheridan                 308232

# %%
demographic.head()
# Out:
#          City    County    Land Area  Households with Under 18  \
# 0     Laramie    Albany  2513.745235                      2075
# 1  Rock River    Albany   200.444000                       165
# 2       Basin  Big Horn   543.951304                       250
# 3  Burlington  Big Horn   137.646214                        63
# 4       Byron  Big Horn   252.489592                       116
#
#    Population Density  Total Families
# 0                5.19         4668.93
# 1                0.41          372.30
# 2                0.66          566.43
# 3                0.17          143.34
# 4                0.31          262.93

# %%
#with the demographic dataset, we can find the cities, land ares, Households with Under 18, Population Density
# and Total Families
demographic = demographic.drop('County', axis = 1)
demographic = demographic.rename(columns = {'City': 'CITY'})
demographic = demographic.groupby('CITY').sum().reset_index()
demographic.head()
# Out:
#       CITY   Land Area  Households with Under 18  Population Density  \
# 0    Afton  853.806650                       497                0.93
# 1    Albin    7.685902                        37                0.10
# 2   Alpine  366.598892                       213                0.40
# 3    Baggs  253.240322                        62                0.06
# 4  Bairoil   29.459830                        18                0.01
#
#    Total Families
# 0         1040.41
# 1           74.87
# 2          446.72
# 3          129.53
# 4           33.70

# %%
parsed_web
# Out:
#                       City|County  \
# 0                   Afton|Lincoln
# 1                   Albin|Laramie
# 2                  Alpine|Lincoln
# 3                    Baggs|Carbon
# 4              Bairoil|Sweetwater
# 5                Bar Nunn|Natrona
# 6                Basin ?|Big Horn
# 7                Bear River|Uinta
# 8              Big Piney|Sublette
# 9               Buffalo ?|Johnson
# 10            Burlington|Big Horn
# 11                  Burns|Laramie
# 12                 Byron|Big Horn
# 13               Casper ?|Natrona
# 14            Cheyenne ??|Laramie
# 15               Chugwater|Platte
# 16             Clearmont|Sheridan
# 17                    Cody ?|Park
# 18              Cokeville|Lincoln
# 19                Cowley|Big Horn
# 20                Dayton|Sheridan
# 21                Deaver|Big Horn
# 22           Diamondville|Lincoln
# 23                   Dixon|Carbon
# 24             Douglas ?|Converse
# 25                 Dubois|Fremont
# 26   East Thermopolis|Hot Springs
# 27               Edgerton|Natrona
# 28            Elk Mountain|Carbon
# 29               Evanston ?|Uinta
# ..                            ...
# 73                    Powell|Park
# 74            Ranchester|Sheridan
# 75               Rawlins ?|Carbon
# 76               Riverside|Carbon
# 77               Riverton|Fremont
# 78              Rock River|Albany
# 79        Rock Springs|Sweetwater
# 80         Rolling Hills|Converse
# 81                Saratoga|Carbon
# 82            Sheridan ?|Sheridan
# 83               Shoshoni|Fremont
# 84                Sinclair|Carbon
# 85      Star Valley Ranch|Lincoln
# 86               Sundance ?|Crook
# 87            Superior|Sweetwater
# 88             Ten Sleep|Washakie
# 89                 Thayne|Lincoln
# 90      Thermopolis ?|Hot Springs
# 91            Torrington ?|Goshen
# 92                   Upton|Weston
# 93           Van Tassell|Niobrara
# 94           Wamsutter|Sweetwater
# 95             Wheatland ?|Platte
# 96             Worland ?|Washakie
# 97                Wright|Campbell
# 98                   Yoder|Goshen
# 99                            NaN
# 100                           NaN
# 101                           NaN
# 102                           NaN
#
#                                          2014 Estimate  \
# 0                                       <td>1,968</td>
# 1                                         <td>185</td>
# 2                                         <td>845</td>
# 3                                         <td>439</td>
# 4                                         <td>107</td>
# 5                                       <td>2,735</td>
# 6                                       <td>1,312</td>
# 7                                         <td>521</td>
# 8                                         <td>538</td>
# 9                                       <td>4,615</td>
# 10                                        <td>332</td>
# 11                                        <td>305</td>
# 12                                        <td>609</td>
# 13                                     <td>40,086</td>
# 14                                     <td>62,845</td>
# 15                                        <td>216</td>
# 16                                        <td>142</td>
# 17                                      <td>9,740</td>
# 18                                        <td>542</td>
# 19                                        <td>718</td>
# 20                                        <td>794</td>
# 21                                        <td>184</td>
# 22                                        <td>740</td>
# 23                                         <td>97</td>
# 24                                      <td>6,423</td>
# 25                                        <td>998</td>
# 26                                        <td>252</td>
# 27                                        <td>199</td>
# 28                                        <td>196</td>
# 29                                     <td>12,190</td>
# ..                                                 ...
# 73                                      <td>6,407</td>
# 74                                        <td>943</td>
# 75                                      <td>9,227</td>
# 76                                         <td>53</td>
# 77                                     <td>10,953</td>
# 78                                        <td>245</td>
# 79                                     <td>24,045</td>
# 80                                        <td>439</td>
# 81                                      <td>1,692</td>
# 82                                     <td>17,916</td>
# 83                                        <td>655</td>
# 84                                        <td>424</td>
# 85                                      <td>1,541</td>
# 86                                      <td>1,239</td>
# 87                                        <td>332</td>
# 88                                        <td>253</td>
# 89                                        <td>364</td>
# 90                                      <td>3,020</td>
# 91                                      <td>6,736</td>
# 92                                      <td>1,104</td>
# 93                                         <td>15</td>
# 94                                        <td>503</td>
# 95                                      <td>3,659</td>
# 96                                      <td>5,366</td>
# 97                                      <td>1,847</td>
# 98                                        <td>161</td>
# 99                               <td colspan="2"></td>
# 100  <td class="navbox-list navbox-even hlist" styl...
# 101                              <td colspan="2"></td>
# 102                              <td colspan="2"></td>
#
#                                            2010 Census  \
# 0                                       <td>1,911</td>
# 1                                         <td>181</td>
# 2                                         <td>828</td>
# 3                                         <td>440</td>
# 4                                         <td>106</td>
# 5                                       <td>2,213</td>
# 6    <td>1,285<sup id="cite_ref-4" class="reference...
# 7                                         <td>518</td>
# 8                                         <td>552</td>
# 9                                       <td>4,585</td>
# 10                                        <td>288</td>
# 11                                        <td>301</td>
# 12                                        <td>593</td>
# 13                                     <td>35,316</td>
# 14                                     <td>59,466</td>
# 15                                        <td>212</td>
# 16                                        <td>142</td>
# 17                                      <td>9,520</td>
# 18                                        <td>535</td>
# 19                                        <td>655</td>
# 20                                        <td>757</td>
# 21                                        <td>178</td>
# 22                                        <td>737</td>
# 23                                         <td>97</td>
# 24                                      <td>6,120</td>
# 25                                        <td>971</td>
# 26                                        <td>254</td>
# 27                                        <td>195</td>
# 28                                        <td>191</td>
# 29                                     <td>12,359</td>
# ..                                                 ...
# 73                                      <td>6,314</td>
# 74                                        <td>855</td>
# 75                                      <td>9,259</td>
# 76                                         <td>52</td>
# 77                                     <td>10,615</td>
# 78                                        <td>245</td>
# 79                                     <td>23,036</td>
# 80                                        <td>440</td>
# 81                                      <td>1,690</td>
# 82                                     <td>17,444</td>
# 83                                        <td>649</td>
# 84                                        <td>433</td>
# 85                                      <td>1,503</td>
# 86                                      <td>1,182</td>
# 87                                        <td>336</td>
# 88                                        <td>260</td>
# 89   <td>366<sup id="cite_ref-5" class="reference">...
# 90                                      <td>3,009</td>
# 91                                      <td>6,501</td>
# 92                                      <td>1,100</td>
# 93                                         <td>15</td>
# 94                                        <td>451</td>
# 95                                      <td>3,627</td>
# 96                                      <td>5,487</td>
# 97                                      <td>1,807</td>
# 98                                        <td>151</td>
# 99          <td class="navbox-abovebelow" colspan="2">
# 100                              <td colspan="2"></td>
# 101  <td class="navbox-list navbox-odd hlist" style...
# 102  <td class="navbox-list navbox-even hlist" styl...
#
#                                            2000 Census
# 0                                       <td>1,818</td>
# 1                                         <td>120</td>
# 2                                         <td>550</td>
# 3                                         <td>348</td>
# 4                                          <td>97</td>
# 5                                         <td>936</td>
# 6                                       <td>1,238</td>
# 7                                           <td>-</td>
# 8                                         <td>408</td>
# 9                                       <td>3,900</td>
# 10                                        <td>250</td>
# 11                                        <td>285</td>
# 12                                        <td>557</td>
# 13                                     <td>32,644</td>
# 14                                     <td>53,011</td>
# 15                                        <td>244</td>
# 16                                        <td>115</td>
# 17                                      <td>8,835</td>
# 18                                        <td>506</td>
# 19                                        <td>560</td>
# 20                                        <td>678</td>
# 21                                        <td>177</td>
# 22                                        <td>716</td>
# 23                                         <td>79</td>
# 24                                      <td>5,288</td>
# 25                                        <td>962</td>
# 26                                        <td>274</td>
# 27                                        <td>169</td>
# 28                                        <td>192</td>
# 29                                     <td>11,507</td>
# ..                                                 ...
# 73                                      <td>5,373</td>
# 74                                        <td>701</td>
# 75                                      <td>8,538</td>
# 76                                         <td>59</td>
# 77                                      <td>9,310</td>
# 78                                        <td>235</td>
# 79                                     <td>18,708</td>
# 80                                        <td>449</td>
# 81                                      <td>1,726</td>
# 82                                     <td>15,804</td>
# 83                                        <td>635</td>
# 84                                        <td>423</td>
# 85                                        <td>776</td>
# 86                                      <td>1,161</td>
# 87                                        <td>244</td>
# 88                                        <td>304</td>
# 89                                        <td>341</td>
# 90                                      <td>3,172</td>
# 91                                      <td>5,776</td>
# 92                                        <td>872</td>
# 93                                         <td>18</td>
# 94                                        <td>261</td>
# 95                                      <td>3,548</td>
# 96                                      <td>5,250</td>
# 97                                      <td>1,347</td>
# 98                                        <td>169</td>
# 99                               <td colspan="2"></td>
# 100  <td class="navbox-list navbox-odd hlist" style...
# 101                           <td style="padding:2px">
# 102                              <td colspan="2"></td>
#
# [103 rows x 4 columns]

# %%
parsed_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 4 columns):
# City|County      99 non-null object
# 2014 Estimate    103 non-null object
# 2010 Census      103 non-null object
# 2000 Census      103 non-null object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %%
parsed_web.columns
# Out:
# Index(['City|County', '2014 Estimate', '2010 Census', '2000 Census'], dtype='object')

# %%
#let's split the city and county column into two seperate columns
parsed_web['City'], parsed_web['County'] = parsed_web['City|County'].str.split('|', 1).str
parsed_web = parsed_web.drop("City|County", axis = 1)
parsed_web = parsed_web.rename(columns = {'City': 'CITY'})

# %%
#let's remove all <td>s from the columns
for val in parsed_web.columns.values:
    parsed_web[val] = parsed_web[val].str.replace("<td>", "")
    parsed_web[val] = parsed_web[val].str.replace("</td>", "")
    #<sup id="cite_ref-5" class="reference"
    parsed_web[val] = parsed_web[val].str.replace("<sup.*?>(.+?)</sup>", "")
    parsed_web[val] = parsed_web[val].str.replace("?", "")

# %%
parsed_web
# Out:
#                                          2014 Estimate  \
# 0                                                1,968
# 1                                                  185
# 2                                                  845
# 3                                                  439
# 4                                                  107
# 5                                                2,735
# 6                                                1,312
# 7                                                  521
# 8                                                  538
# 9                                                4,615
# 10                                                 332
# 11                                                 305
# 12                                                 609
# 13                                              40,086
# 14                                              62,845
# 15                                                 216
# 16                                                 142
# 17                                               9,740
# 18                                                 542
# 19                                                 718
# 20                                                 794
# 21                                                 184
# 22                                                 740
# 23                                                  97
# 24                                               6,423
# 25                                                 998
# 26                                                 252
# 27                                                 199
# 28                                                 196
# 29                                              12,190
# ..                                                 ...
# 73                                               6,407
# 74                                                 943
# 75                                               9,227
# 76                                                  53
# 77                                              10,953
# 78                                                 245
# 79                                              24,045
# 80                                                 439
# 81                                               1,692
# 82                                              17,916
# 83                                                 655
# 84                                                 424
# 85                                               1,541
# 86                                               1,239
# 87                                                 332
# 88                                                 253
# 89                                                 364
# 90                                               3,020
# 91                                               6,736
# 92                                               1,104
# 93                                                  15
# 94                                                 503
# 95                                               3,659
# 96                                               5,366
# 97                                               1,847
# 98                                                 161
# 99                                    <td colspan="2">
# 100  <td class="navbox-list navbox-even hlist" styl...
# 101                                   <td colspan="2">
# 102                                   <td colspan="2">
#
#                                            2010 Census  \
# 0                                                1,911
# 1                                                  181
# 2                                                  828
# 3                                                  440
# 4                                                  106
# 5                                                2,213
# 6                                                1,285
# 7                                                  518
# 8                                                  552
# 9                                                4,585
# 10                                                 288
# 11                                                 301
# 12                                                 593
# 13                                              35,316
# 14                                              59,466
# 15                                                 212
# 16                                                 142
# 17                                               9,520
# 18                                                 535
# 19                                                 655
# 20                                                 757
# 21                                                 178
# 22                                                 737
# 23                                                  97
# 24                                               6,120
# 25                                                 971
# 26                                                 254
# 27                                                 195
# 28                                                 191
# 29                                              12,359
# ..                                                 ...
# 73                                               6,314
# 74                                                 855
# 75                                               9,259
# 76                                                  52
# 77                                              10,615
# 78                                                 245
# 79                                              23,036
# 80                                                 440
# 81                                               1,690
# 82                                              17,444
# 83                                                 649
# 84                                                 433
# 85                                               1,503
# 86                                               1,182
# 87                                                 336
# 88                                                 260
# 89                                                 366
# 90                                               3,009
# 91                                               6,501
# 92                                               1,100
# 93                                                  15
# 94                                                 451
# 95                                               3,627
# 96                                               5,487
# 97                                               1,807
# 98                                                 151
# 99          <td class="navbox-abovebelow" colspan="2">
# 100                                   <td colspan="2">
# 101  <td class="navbox-list navbox-odd hlist" style...
# 102  <td class="navbox-list navbox-even hlist" styl...
#
#                                            2000 Census               CITY  \
# 0                                                1,818              Afton
# 1                                                  120              Albin
# 2                                                  550             Alpine
# 3                                                  348              Baggs
# 4                                                   97            Bairoil
# 5                                                  936           Bar Nunn
# 6                                                1,238             Basin
# 7                                                    -         Bear River
# 8                                                  408          Big Piney
# 9                                                3,900           Buffalo
# 10                                                 250         Burlington
# 11                                                 285              Burns
# 12                                                 557              Byron
# 13                                              32,644            Casper
# 14                                              53,011          Cheyenne
# 15                                                 244          Chugwater
# 16                                                 115          Clearmont
# 17                                               8,835              Cody
# 18                                                 506          Cokeville
# 19                                                 560             Cowley
# 20                                                 678             Dayton
# 21                                                 177             Deaver
# 22                                                 716       Diamondville
# 23                                                  79              Dixon
# 24                                               5,288           Douglas
# 25                                                 962             Dubois
# 26                                                 274   East Thermopolis
# 27                                                 169           Edgerton
# 28                                                 192       Elk Mountain
# 29                                              11,507          Evanston
# ..                                                 ...                ...
# 73                                               5,373             Powell
# 74                                                 701         Ranchester
# 75                                               8,538           Rawlins
# 76                                                  59          Riverside
# 77                                               9,310           Riverton
# 78                                                 235         Rock River
# 79                                              18,708       Rock Springs
# 80                                                 449      Rolling Hills
# 81                                               1,726           Saratoga
# 82                                              15,804          Sheridan
# 83                                                 635           Shoshoni
# 84                                                 423           Sinclair
# 85                                                 776  Star Valley Ranch
# 86                                               1,161          Sundance
# 87                                                 244           Superior
# 88                                                 304          Ten Sleep
# 89                                                 341             Thayne
# 90                                               3,172       Thermopolis
# 91                                               5,776        Torrington
# 92                                                 872              Upton
# 93                                                  18        Van Tassell
# 94                                                 261          Wamsutter
# 95                                               3,548         Wheatland
# 96                                               5,250           Worland
# 97                                               1,347             Wright
# 98                                                 169              Yoder
# 99                                    <td colspan="2">                NaN
# 100  <td class="navbox-list navbox-odd hlist" style...                NaN
# 101                           <td style="padding:2px">                NaN
# 102                                   <td colspan="2">                NaN
#
#           County
# 0        Lincoln
# 1        Laramie
# 2        Lincoln
# 3         Carbon
# 4     Sweetwater
# 5        Natrona
# 6       Big Horn
# 7          Uinta
# 8       Sublette
# 9        Johnson
# 10      Big Horn
# 11       Laramie
# 12      Big Horn
# 13       Natrona
# 14       Laramie
# 15        Platte
# 16      Sheridan
# 17          Park
# 18       Lincoln
# 19      Big Horn
# 20      Sheridan
# 21      Big Horn
# 22       Lincoln
# 23        Carbon
# 24      Converse
# 25       Fremont
# 26   Hot Springs
# 27       Natrona
# 28        Carbon
# 29         Uinta
# ..           ...
# 73          Park
# 74      Sheridan
# 75        Carbon
# 76        Carbon
# 77       Fremont
# 78        Albany
# 79    Sweetwater
# 80      Converse
# 81        Carbon
# 82      Sheridan
# 83       Fremont
# 84        Carbon
# 85       Lincoln
# 86         Crook
# 87    Sweetwater
# 88      Washakie
# 89       Lincoln
# 90   Hot Springs
# 91        Goshen
# 92        Weston
# 93      Niobrara
# 94    Sweetwater
# 95        Platte
# 96      Washakie
# 97      Campbell
# 98        Goshen
# 99           NaN
# 100          NaN
# 101          NaN
# 102          NaN
#
# [103 rows x 5 columns]

# %%
#let's drop the las 4 rows
parsed_web = parsed_web[:-4]

# %%
#now we have to change the type of "2010" census to string
parsed_web['2010 Census'] = parsed_web['2010 Census'].astype(str)
parsed_web['2010 Census'] = parsed_web['2010 Census'].str.replace(",", "")
parsed_web['2010 Census'] = pd.to_numeric(parsed_web['2010 Census'])
# Out:
# /Users/zahrafarhadi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zahrafarhadi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/zahrafarhadi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#now let's group the cities and keep the necessary colums

parsed_web = parsed_web.filter(['CITY', '2010 Census'], axis = 1)
parsed_web = parsed_web.groupby('CITY').sum().reset_index()

# %%
parsed_web.head()
# Out:
#       CITY  2010 Census
# 0    Afton         1911
# 1    Albin          181
# 2   Alpine          828
# 3    Baggs          440
# 4  Bairoil          106

# %% [markdown]
# ## Joining the tables

# %%
sales_2010.set_index('CITY')
demographic.set_index('CITY')
parsed_web.set_index('CITY')
#display(sales_2010) #city, total padacity sales
#display(demographic) #city, land area, household under 18, population density, total families
#display(parsed_web) #city, 2010 census

table = sales_2010.join(parsed_web.set_index('CITY'), on='CITY')
display(table)
table = table.join(demographic.set_index('CITY'), on='CITY')
display(table)
# Out:
#             CITY  Total Pawdacity Sales  2010 Census
# 0        Buffalo                 185328          NaN
# 1         Casper                 317736          NaN
# 2       Cheyenne                 917892          NaN
# 3           Cody                 218376          NaN
# 4        Douglas                 208008          NaN
# 5       Evanston                 283824          NaN
# 6       Gillette                 543132          NaN
# 7         Powell                 233928       6314.0
# 8       Riverton                 303264      10615.0
# 9   Rock Springs                 253584      23036.0
# 10      Sheridan                 308232          NaN
#             CITY  Total Pawdacity Sales  2010 Census    Land Area  \
# 0        Buffalo                 185328          NaN  3115.507500
# 1         Casper                 317736          NaN  3894.309100
# 2       Cheyenne                 917892          NaN  1500.178400
# 3           Cody                 218376          NaN  2998.956960
# 4        Douglas                 208008          NaN  1829.465100
# 5       Evanston                 283824          NaN   999.497100
# 6       Gillette                 543132          NaN  2748.852900
# 7         Powell                 233928       6314.0  2673.574550
# 8       Riverton                 303264      10615.0  4796.859815
# 9   Rock Springs                 253584      23036.0  6620.201916
# 10      Sheridan                 308232          NaN  1893.977048
#
#     Households with Under 18  Population Density  Total Families
# 0                        746                1.55         1819.50
# 1                       7788               11.16         8756.32
# 2                       7158               20.34        14612.64
# 3                       1403                1.82         3515.62
# 4                        832                1.46         1744.08
# 5                       1486                4.95         2712.64
# 6                       4052                5.80         7189.43
# 7                       1251                1.62         3134.18
# 8                       2680                2.34         5556.49
# 9                       4022                2.78         7572.18
# 10                      2646                8.98         6039.71

# %%
table.describe()
# Out:
#          Land Area  Households with Under 18  Population Density  \
# count    99.000000                 99.000000           99.000000
# mean    827.837571                582.353535            1.145859
# std    1243.493105               1249.994566            2.601399
# min       7.685902                  2.000000            0.010000
# 25%     100.854266                 54.500000            0.095000
# 50%     253.240322                160.000000            0.350000
# 75%     987.769764                404.000000            0.980000
# max    6620.201916               7788.000000           20.340000
#
#        Total Families  Total Pawdacity Sales
# count       99.000000              11.000000
# mean      1148.407677          343027.636364
# std       2183.310426          213538.712215
# min          5.790000          185328.000000
# 25%        114.005000          226152.000000
# 50%        332.280000          283824.000000
# 75%        858.695000          312984.000000
# max      14612.640000          917892.000000

# %%
#now let's get the sum and average of the columns
for val in table.columns.values:
    if val != "CITY":
        _sum = table[val].sum()
        _avg = table[val].mean()
        print("{} - sum = {} \t avg = {}".format(val, _sum, _avg))
        #print(table.val)
        #print(val + 'va')
# Out:
# Land Area - sum = 81955.91952966899 	 avg = 827.837571006758
# Households with Under 18 - sum = 57653 	 avg = 582.3535353535353
# Population Density - sum = 113.44 	 avg = 1.145858585858586
# Total Families - sum = 113692.36000000003 	 avg = 1148.4076767676765
# Total Pawdacity Sales - sum = 3773304.0 	 avg = 343027.63636363635
